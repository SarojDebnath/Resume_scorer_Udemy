# %%
import fitz

pdf_path = "C:/Users/sarojd/Resume_scorer_Udemy/data/CV_Saroj.pdf"

with fitz.open(pdf_path) as doc:
    print(f"Total pages: {doc.page_count}")
    
    for page_num, page in enumerate(doc, start=1):
        text = page.get_text()
        print(f"\n--- Page {page_num} ---\n{text}")
# Out:
# Total pages: 1
#
# --- Page 1 ---
# Saroj Debnath
# ripandebnath2405@gmail.com
# SarojDebnath,
#  Github,Meiningen-98617, Germany
#
#
# SKILLS:
# Computer Vision || Deep Learning || Python || C++ || Embedded Systems || PLC (Siemens TIA) || CAD || Matlab || Linux
# || Networking with Socket Python || SMT Soldering || Intel Realsense || OAK camera || Yaskawa || Igus || Epson || UR ||
# AI Tools || SQL || PostGRE SQL || SAP ||MiR Autonomous Robot || Git
# EXPERIENCE:
# Adtran Networks SE
# Meiningen,Germany
# Automation Engineer
# August 2023- Present
# 1. Developed and Deployed an Automatic Machine Plugging System with 3D Vision.
# •
# Calculated target object position with reference to Universal Robot position with maximum inaccuracy of
# 0.1 mm.
# •
# Scanning label to read inventory data with camera and OCR.
# •
# Architectures used are YOLOv12, Pointnet.
# •
# Deployed IBVS for achieving stability and accuracy.
# •
# ...
